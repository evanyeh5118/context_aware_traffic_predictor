# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import numpy as np
import matplotlib.pyplot as plt
import pickle
import torch

from libs.TrafficGenerator import DatasetConvertor 
from libs.TrafficPredictor.ContextAssisted import PreparingDataset as PreparingDatasetCA
from libs.TrafficPredictor.ContextAssisted import trainModelByDefaultSetting as trainModelCA
from libs.TrafficPredictor.ContextAssisted import evaluateModel as evaluateModelCA
from libs.TrafficPredictor.ContextAssisted import createModel as createModelCA
from libs.TrafficPredictor.ContextPerfect import PreparingDataset as PreparingDatasetPerfect
from libs.TrafficPredictor.ContextPerfect import trainModelByDefaultSetting as trainModelPerfect
from libs.TrafficPredictor.ContextPerfect import evaluateModel as evaluateModelPerfect
from libs.TrafficPredictor.ContextPerfect import createModel as createModelPerfect
from libs.TrafficPredictor.ContextFree import PreparingDataset as PreparingDatasetCF
from libs.TrafficPredictor.ContextFree import trainModelByDefaultSetting as trainModelCF
from libs.TrafficPredictor.ContextFree import evaluateModel as evaluateModelCF
from libs.TrafficPredictor.ContextFree import createModel as createModelCF
from libs import encode_float_filename, decode_float_filename

# %%
stringFile = encode_float_filename(0.5)
floatFile = decode_float_filename(stringFile)
print(stringFile)
print(floatFile)
# Out:
# 5_00e-01.txt
# 0.5

# %%
dbParams = 0.01
direction = "forward"
#dbParams = 0.15
#direction = "backward"
mode = "fixed"
#mode = "adaptive"
alpha = 0.5
lenWindow_list = [10]
train_ratio = 0.8

rawDatasetFolder = "Dataset"
datasetConverter = DatasetConvertor(rawDatasetFolder)
datasetConverter.processDataset(dbParameter=dbParams, alpha=alpha, mode=mode, direction=direction)
thumbUnit = datasetConverter.getDataUnit('thumb_fr')
#thumbUnit = datasetConverter.getDataUnit('thumb_bk')
# Out:
# ========== thumb ============
# Forward: Compression rate:0.22314470485360394
# ========== index ============
# Forward: Compression rate:0.24555334544091786
# ========== middle ============
# Forward: Compression rate:0.24907031047306064

# %%
for lenWindow in lenWindow_list:
    print(f"================== lenWindow = {lenWindow} =================")
    trainDataAugment = True
    verbose = True

    paramsCF = {}
    paramsCF['lenWindow'] = lenWindow
    paramsCF['lenSource'] = 10
    paramsCF['lenTarget'] = 1
    paramsCF['trainRatio'] = train_ratio
    paramsCF['dataAugment'] = trainDataAugment

    trainData, testData = PreparingDatasetCF(thumbUnit, paramsCF, verbose=verbose)

    bestWeightsCF, _, _, modleParametersCF = trainModelCF(
    paramsCF['lenSource'], paramsCF['lenTarget'], trainData, testData, verbose=verbose)

    trafficModelCF, _ = createModelCF(modleParametersCF)
    trafficModelCF.load_state_dict(bestWeightsCF)

    paramsCF['dataAugment'] = False
    trainDataValid, testDataValid = PreparingDatasetCF(thumbUnit, paramsCF, verbose=verbose)
    actual_trafficCF_train, predicted_trafficCF_train = evaluateModelCF(trafficModelCF, trainDataValid)
    resultsTrain = {}
    resultsTrain['trafficTarget_actual'] = actual_trafficCF_train
    resultsTrain['trafficTarget_predicted'] = predicted_trafficCF_train
    actual_trafficCF_test, predicted_trafficCF_test = evaluateModelCF(trafficModelCF, testDataValid)
    resultsTest = {}
    resultsTest['trafficTarget_actual'] = actual_trafficCF_test
    resultsTest['trafficTarget_predicted'] = predicted_trafficCF_test

    plt.plot(resultsTest['trafficTarget_actual'][0:200])
    plt.plot(resultsTest['trafficTarget_predicted'][0:200])
    plt.show()

    #============= Save Results =============
    dbpString = encode_float_filename(dbParams)
    with open(f"Results/TrafficPredictor/evaluate/CF/{direction}_{lenWindow}_{mode}_{dbpString}_train.pkl", "wb") as file:
        pickle.dump(resultsTrain, file)
    with open(f"Results/TrafficPredictor/evaluate/CF/{direction}_{lenWindow}_{mode}_{dbpString}_test.pkl", "wb") as file:
        pickle.dump(resultsTest, file)
# Out:
# ================== lenWindow = 10 =================
# Train size: 83253, Test size: 20814
# Size of train loader: 21, Size of test loader: 6
# Used device: cuda
# Size of model: 46969
# Seq2Seq(
#   (encoder): Encoder(
#     (lstm_layers): ModuleList(
#       (0): LSTM(1, 12, bidirectional=True)
#       (1-5): 5 x LSTM(24, 12, bidirectional=True)
#     )
#     (ln_layers): ModuleList(
#       (0-5): 6 x LayerNorm((24,), eps=1e-05, elementwise_affine=True)
#     )
#     (residual_projections): ModuleList(
#       (0): Linear(in_features=1, out_features=24, bias=True)
#       (1-5): 5 x None
#     )
#   )
#   (decoder): Decoder(
#     (lstm_layers): ModuleList(
#       (0): LSTM(1, 24)
#       (1-5): 5 x LSTM(24, 24)
#     )
#     (ln_layers): ModuleList(
#       (0-5): 6 x LayerNorm((24,), eps=1e-05, elementwise_affine=True)
#     )
#     (residual_projections): ModuleList(
#       (0): Linear(in_features=1, out_features=24, bias=True)
#       (1-5): 5 x None
#     )
#     (fc_out): Linear(in_features=24, out_features=1, bias=True)
#   )
# )
# Epoch [1/50], Train Loss: 2.311873, Validation Loss: 1.357014
# Epoch [2/50], Train Loss: 1.476101, Validation Loss: 1.350637
# Epoch [3/50], Train Loss: 1.440533, Validation Loss: 1.332951
# Epoch [4/50], Train Loss: 1.431547, Validation Loss: 1.329639
# Epoch [5/50], Train Loss: 1.428129, Validation Loss: 1.337607
# Epoch [6/50], Train Loss: 1.422824, Validation Loss: 1.335122
# Epoch [7/50], Train Loss: 1.418706, Validation Loss: 1.331206
# Epoch [8/50], Train Loss: 1.415957, Validation Loss: 1.327263
# Epoch [9/50], Train Loss: 1.415518, Validation Loss: 1.325522
# Epoch [10/50], Train Loss: 1.403436, Validation Loss: 1.329983
# Epoch [11/50], Train Loss: 1.404715, Validation Loss: 1.327460
# Epoch [12/50], Train Loss: 1.402873, Validation Loss: 1.328807
# Epoch [13/50], Train Loss: 1.401172, Validation Loss: 1.334171
# Epoch [14/50], Train Loss: 1.400255, Validation Loss: 1.327871
# Epoch [15/50], Train Loss: 1.392761, Validation Loss: 1.345349
# Epoch [16/50], Train Loss: 1.397608, Validation Loss: 1.339540
# Epoch [17/50], Train Loss: 1.395610, Validation Loss: 1.339248
# Epoch [18/50], Train Loss: 1.396829, Validation Loss: 1.336447
# Epoch [19/50], Train Loss: 1.391382, Validation Loss: 1.353429
# Epoch [20/50], Train Loss: 1.395989, Validation Loss: 1.377897
# Epoch [21/50], Train Loss: 1.392534, Validation Loss: 1.341566
# Epoch [22/50], Train Loss: 1.385646, Validation Loss: 1.348566
# Epoch [23/50], Train Loss: 1.383949, Validation Loss: 1.348354
# Epoch [24/50], Train Loss: 1.380651, Validation Loss: 1.339421
# Epoch [25/50], Train Loss: 1.386511, Validation Loss: 1.368329
# Epoch [26/50], Train Loss: 1.385088, Validation Loss: 1.353421
# Epoch [27/50], Train Loss: 1.379060, Validation Loss: 1.339811
# Epoch [28/50], Train Loss: 1.371754, Validation Loss: 1.355103
# Epoch [29/50], Train Loss: 1.376106, Validation Loss: 1.346285
# Epoch [30/50], Train Loss: 1.378011, Validation Loss: 1.339770
# Epoch [31/50], Train Loss: 1.368751, Validation Loss: 1.354924
# Epoch [32/50], Train Loss: 1.376145, Validation Loss: 1.362630
# Epoch [33/50], Train Loss: 1.363133, Validation Loss: 1.362328
# Epoch [34/50], Train Loss: 1.363492, Validation Loss: 1.346718
# Epoch [35/50], Train Loss: 1.362518, Validation Loss: 1.351392
# Epoch [36/50], Train Loss: 1.365330, Validation Loss: 1.353040
# Epoch [37/50], Train Loss: 1.352835, Validation Loss: 1.347150
# Epoch [38/50], Train Loss: 1.363495, Validation Loss: 1.353433
# Epoch [39/50], Train Loss: 1.355445, Validation Loss: 1.340401
# Epoch [40/50], Train Loss: 1.357085, Validation Loss: 1.354826
# Epoch [41/50], Train Loss: 1.349283, Validation Loss: 1.354697
# Epoch [42/50], Train Loss: 1.351694, Validation Loss: 1.354213
# Epoch [43/50], Train Loss: 1.343883, Validation Loss: 1.359581
# Epoch [44/50], Train Loss: 1.348765, Validation Loss: 1.345428
# Epoch [45/50], Train Loss: 1.349390, Validation Loss: 1.380305
# Epoch [46/50], Train Loss: 1.348324, Validation Loss: 1.355156
# Epoch [47/50], Train Loss: 1.342140, Validation Loss: 1.350095
# Epoch [48/50], Train Loss: 1.339458, Validation Loss: 1.368367
# Epoch [49/50], Train Loss: 1.336127, Validation Loss: 1.361603
# Epoch [50/50], Train Loss: 1.330361, Validation Loss: 1.356691
# Train size: 83253, Test size: 20814

# %%
for lenWindow in lenWindow_list:
    print(f"================== lenWindow = {lenWindow} =================")
    trainDataAugment = True
    verbose = True

    paramsCA = {}
    paramsCA['lenSource'] = lenWindow
    paramsCA['lenTarget'] = lenWindow
    paramsCA['trainRatio'] = train_ratio
    paramsCA['dataAugment'] = trainDataAugment
    paramsCA['smoothFc'] = 1.5
    paramsCA['smoothOrder'] = 3

    #============= Training =============
    trainData, testData = PreparingDatasetCA(thumbUnit, paramsCA, verbose=verbose)
    (sources, _, lastTranmittedContext, _, _, _, _, _) = trainData
    print(sources.shape)
    print(lastTranmittedContext.shape)
    bestWeightsCA, _, _, modleParametersCA = trainModelCA(
    paramsCA['lenSource'], paramsCA['lenTarget'], trainData, testData, verbose=verbose)

    #============= Evaluatation =============
    trafficModelCA, _ = createModelCA(modleParametersCA)
    trafficModelCA.load_state_dict(bestWeightsCA)
    paramsValid = paramsCA.copy()
    paramsValid['dataAugment'] = False
    trainData, testData = PreparingDatasetCA(thumbUnit, paramsValid, verbose=verbose)
    resultsTrain = evaluateModelCA(trafficModelCA, trainData)
    resultsTest = evaluateModelCA(trafficModelCA, testData)

    #print(f"actual_class_shape: {resultsTrain['classDistribu_actual'].shape}, predicted_class_shape: {resultsTrain['classDistribu_predicted'].shape}")

    plt.plot(resultsTest['trafficTarget_actual'][0:200])
    plt.plot(resultsTest['trafficTarget_predicted'][0:200])
    plt.show()

    #============= Save Results =============
    dbpString = encode_float_filename(dbParams)
    with open(f"Results/TrafficPredictor/evaluate/CA/{direction}_{lenWindow}_{mode}_{dbpString}_train.pkl", "wb") as file:
        pickle.dump(resultsTrain, file)
    with open(f"Results/TrafficPredictor/evaluate/CA/{direction}_{lenWindow}_{mode}_{dbpString}_test.pkl", "wb") as file:
        pickle.dump(resultsTest, file)
    with open(f"Results/TrafficPredictor/modelParams/{direction}_{lenWindow}_{mode}_{dbpString}.pkl", "wb") as file:
        pickle.dump(modleParametersCA, file)
    torch.save(bestWeightsCA, f"Results/TrafficPredictor/model/{direction}_{lenWindow}_{mode}_{dbpString}.pth")
# Out:
# ================== lenWindow = 10 =================
# Train size: 83253, Test size: 20814
# (83233, 10, 3)
# (83233, 1, 3)
# Size of train loader: 11, Size of test loader: 3
# Used device: cuda
# Size of model: 19661
# TrafficPredictorContextAssisted(
#   (dbf2traffic): DeadFeaturesToTrafficLayer(
#     (input_layer): Sequential(
#       (0): Linear(in_features=66, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.8, inplace=False)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.8, inplace=False)
#       )
#     )
#     (trans2transmission_layer): Linear(in_features=64, out_features=10, bias=True)
#     (sigmoid): Sigmoid()
#     (trans2traffic_layer): Linear(in_features=74, out_features=1, bias=True)
#     (trans2trafficClass_layer): Linear(in_features=74, out_features=11, bias=True)
#   )
#   (contextAdjuster): ContextAdjuster(
#     (layers): Sequential(
#       (Linear_1): Linear(in_features=3, out_features=12, bias=True)
#       (BatchNorm_1): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_1): ReLU()
#       (Dropout_1): Dropout(p=0.8, inplace=False)
#       (Linear_2): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_2): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_2): ReLU()
#       (Dropout_2): Dropout(p=0.8, inplace=False)
#       (Linear_3): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_3): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_3): ReLU()
#       (Dropout_3): Dropout(p=0.8, inplace=False)
#       (Linear_4): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_4): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_4): ReLU()
#       (Dropout_4): Dropout(p=0.8, inplace=False)
#       (Linear_5): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_5): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_5): ReLU()
#       (Dropout_5): Dropout(p=0.8, inplace=False)
#     )
#     (output_layer): Linear(in_features=12, out_features=3, bias=True)
#     (sigmoid): Sigmoid()
#   )
#   (reluOut): ReLU()
# )
# Epoch [1/50], Train Loss: 1031.0557, Validation Loss: 498.4593, Validation Loss (Traffic): 6.1616
# Epoch [2/50], Train Loss: 585.2577, Validation Loss: 508.2528, Validation Loss (Traffic): 6.1616
# Epoch [3/50], Train Loss: 509.2955, Validation Loss: 476.8851, Validation Loss (Traffic): 6.1616
# Epoch [4/50], Train Loss: 479.1316, Validation Loss: 475.5536, Validation Loss (Traffic): 6.1616
# Epoch [5/50], Train Loss: 465.3297, Validation Loss: 450.2302, Validation Loss (Traffic): 6.1616
# Epoch [6/50], Train Loss: 457.3118, Validation Loss: 429.4963, Validation Loss (Traffic): 4.3216
# Epoch [7/50], Train Loss: 446.7160, Validation Loss: 434.6748, Validation Loss (Traffic): 4.6662
# Epoch [8/50], Train Loss: 439.5464, Validation Loss: 424.5748, Validation Loss (Traffic): 4.2314
# Epoch [9/50], Train Loss: 437.2305, Validation Loss: 427.4607, Validation Loss (Traffic): 6.1614
# Epoch [10/50], Train Loss: 431.1392, Validation Loss: 424.6371, Validation Loss (Traffic): 5.6528
# Epoch [11/50], Train Loss: 425.9904, Validation Loss: 417.3401, Validation Loss (Traffic): 1.9539
# Epoch [12/50], Train Loss: 422.2743, Validation Loss: 399.3363, Validation Loss (Traffic): 1.6368
# Epoch [13/50], Train Loss: 418.2966, Validation Loss: 408.4280, Validation Loss (Traffic): 4.7840
# Epoch [14/50], Train Loss: 415.5879, Validation Loss: 399.7765, Validation Loss (Traffic): 1.2166
# Epoch [15/50], Train Loss: 413.2555, Validation Loss: 412.4554, Validation Loss (Traffic): 1.2057
# Epoch [16/50], Train Loss: 410.8928, Validation Loss: 394.7176, Validation Loss (Traffic): 1.0822
# Epoch [17/50], Train Loss: 409.1234, Validation Loss: 396.1737, Validation Loss (Traffic): 1.0671
# Epoch [18/50], Train Loss: 408.4719, Validation Loss: 401.0711, Validation Loss (Traffic): 2.0623
# Epoch [19/50], Train Loss: 405.2823, Validation Loss: 400.1002, Validation Loss (Traffic): 1.4403
# Epoch [20/50], Train Loss: 402.7332, Validation Loss: 385.6850, Validation Loss (Traffic): 1.0221
# Epoch [21/50], Train Loss: 402.2452, Validation Loss: 399.5682, Validation Loss (Traffic): 1.2527
# Epoch [22/50], Train Loss: 400.2506, Validation Loss: 417.0745, Validation Loss (Traffic): 1.3670
# Epoch [23/50], Train Loss: 398.4217, Validation Loss: 391.0104, Validation Loss (Traffic): 1.0980
# Epoch [24/50], Train Loss: 398.2940, Validation Loss: 383.3400, Validation Loss (Traffic): 0.9813
# Epoch [25/50], Train Loss: 397.2592, Validation Loss: 390.0759, Validation Loss (Traffic): 1.0019
# Epoch [26/50], Train Loss: 396.8312, Validation Loss: 380.5702, Validation Loss (Traffic): 0.9782
# Epoch [27/50], Train Loss: 396.8255, Validation Loss: 382.8159, Validation Loss (Traffic): 1.0008
# Epoch [28/50], Train Loss: 395.1689, Validation Loss: 380.7135, Validation Loss (Traffic): 0.9878
# Epoch [29/50], Train Loss: 394.2171, Validation Loss: 381.3815, Validation Loss (Traffic): 0.9888
# Epoch [30/50], Train Loss: 393.0836, Validation Loss: 387.7030, Validation Loss (Traffic): 1.0272
# Epoch [31/50], Train Loss: 394.1841, Validation Loss: 377.6995, Validation Loss (Traffic): 0.9479
# Epoch [32/50], Train Loss: 393.2858, Validation Loss: 385.8946, Validation Loss (Traffic): 1.1311
# Epoch [33/50], Train Loss: 392.3374, Validation Loss: 384.6340, Validation Loss (Traffic): 1.0259
# Epoch [34/50], Train Loss: 392.3903, Validation Loss: 379.9286, Validation Loss (Traffic): 0.9562
# Epoch [35/50], Train Loss: 391.3074, Validation Loss: 376.7692, Validation Loss (Traffic): 0.9548
# Epoch [36/50], Train Loss: 391.5771, Validation Loss: 383.3307, Validation Loss (Traffic): 1.0375
# Epoch [37/50], Train Loss: 391.4052, Validation Loss: 381.6260, Validation Loss (Traffic): 1.0289
# Epoch [38/50], Train Loss: 390.5094, Validation Loss: 376.7688, Validation Loss (Traffic): 0.9503
# Epoch [39/50], Train Loss: 390.2581, Validation Loss: 378.4313, Validation Loss (Traffic): 0.9651
# Epoch [40/50], Train Loss: 390.7092, Validation Loss: 387.7768, Validation Loss (Traffic): 1.1135
# Epoch [41/50], Train Loss: 390.1892, Validation Loss: 378.4689, Validation Loss (Traffic): 0.9761
# Epoch [42/50], Train Loss: 390.5322, Validation Loss: 377.7132, Validation Loss (Traffic): 0.9652
# Epoch [43/50], Train Loss: 389.7855, Validation Loss: 380.4404, Validation Loss (Traffic): 1.0187
# Epoch [44/50], Train Loss: 389.8225, Validation Loss: 378.7197, Validation Loss (Traffic): 0.9809
# Epoch [45/50], Train Loss: 389.9107, Validation Loss: 375.2617, Validation Loss (Traffic): 0.9418
# Epoch [46/50], Train Loss: 389.4511, Validation Loss: 377.1934, Validation Loss (Traffic): 0.9886
# Epoch [47/50], Train Loss: 389.0896, Validation Loss: 381.0242, Validation Loss (Traffic): 1.0873
# Epoch [48/50], Train Loss: 389.2870, Validation Loss: 378.4957, Validation Loss (Traffic): 1.0128
# Epoch [49/50], Train Loss: 388.6376, Validation Loss: 380.1225, Validation Loss (Traffic): 1.0151
# Epoch [50/50], Train Loss: 389.0973, Validation Loss: 379.8392, Validation Loss (Traffic): 0.9884
# Train size: 83253, Test size: 20814
