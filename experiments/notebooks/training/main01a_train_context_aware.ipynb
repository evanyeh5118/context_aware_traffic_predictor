# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import numpy as np
import matplotlib.pyplot as plt

import pickle
import json
import sys
sys.path.append("../../../")

from src.context_aware.config import ModelConfig, TrainingConfig, MetaConfig
from src.dataset_manager import DatasetConvertor 
from src.context_aware.preprocessing import PreprocessingDataset
from src.context_aware.models import createModel
from src.context_aware.training import trainModel
from src.context_aware.evaluation import evaluateModel

# %%
rawDatasetFolder = "../../../data/raw"
dpdrDatasetFolder = "../../../data/processed/dpdr"
configPath = "../../config/combined_flows_forward_20.json"
modelFolder = "../../../data/models/context_aware"
verbose = True

# %%
datasetConverter = DatasetConvertor(rawDatasetFolder, randomFlag=False)
with open(configPath, "r") as f:
    config = json.load(f)

name = config.get("NAME")
len_window = config.get("LEN_WINDOW")
dim_data = len(config.get("CONTEXT_IDXS"))
train_ratio = config.get("TRAIN_RATIO")

# =============== Preprocessing ===============
datasetConverter.addDataUnit(config)
dataUnit = datasetConverter.getDataUnit(name)
max_vals, min_vals = dataUnit.getMaxMinMbnVals()
metaConfig = MetaConfig.initialize(
    dim_data=dim_data, 
    window_length=len_window, 
    max_vals=max_vals, 
    min_vals=min_vals
)
trainDataUnit, testDataUnit = dataUnit.split(train_ratio)
dataProcessor = PreprocessingDataset(metaConfig)
trainData = dataProcessor.process(trainDataUnit, dataAugment=True, filterMode='filtfilt')
testData = dataProcessor.process(testDataUnit, dataAugment=False, filterMode='filtfilt')

# =============== Training ===============
modelConfig = ModelConfig.from_meta_config(metaConfig)
model, device = createModel(modelConfig)
trainingConfig = TrainingConfig()
model, avg_train_loss_history, avg_test_loss_history = trainModel(
    model, trainData, testData, trainingConfig, verbose=verbose, 
    model_path=f"{modelFolder}/{name}.pth"
)

# =============== Save ===============
testDataUnit.saveDataUnit(f"{dpdrDatasetFolder}/{name}.csv")
with open(f"{modelFolder}/{name}_modelConfig.pkl", "wb") as f:
    pickle.dump(modelConfig, f)
with open(f"{modelFolder}/{name}_metaConfig.pkl", "wb") as f:
    pickle.dump(metaConfig, f)
# Out:
# Size of train loader: 9, Size of test loader: 1
# Used device: cuda:0
# Size of model: 32066
# TrafficPredictorContextAssisted(
#   (dbf2traffic): DeadFeaturesToTrafficLayer(
#     (input_layer): Sequential(
#       (0): Linear(in_features=231, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.8, inplace=False)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.8, inplace=False)
#       )
#     )
#     (trans2transmission_layer): Linear(in_features=64, out_features=20, bias=True)
#     (sigmoid): Sigmoid()
#     (trans2traffic_layer): Linear(in_features=84, out_features=1, bias=True)
#     (trans2trafficClass_layer): Linear(in_features=84, out_features=21, bias=True)
#   )
#   (contextAdjuster): ContextAdjuster(
#     (layers): Sequential(
#       (Linear_1): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_1): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_1): ReLU()
#       (Dropout_1): Dropout(p=0.8, inplace=False)
#       (Linear_2): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_2): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_2): ReLU()
#       (Dropout_2): Dropout(p=0.8, inplace=False)
#       (Linear_3): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_3): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_3): ReLU()
#       (Dropout_3): Dropout(p=0.8, inplace=False)
#       (Linear_4): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_4): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_4): ReLU()
#       (Dropout_4): Dropout(p=0.8, inplace=False)
#       (Linear_5): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_5): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_5): ReLU()
#       (Dropout_5): Dropout(p=0.8, inplace=False)
#     )
#     (output_layer): Linear(in_features=12, out_features=12, bias=True)
#     (sigmoid): Sigmoid()
#   )
#   (reluOut): ReLU()
# )
# Epoch [1/100], Train Loss: 3636.9714, Validation Loss: 2016.3966, Validation Loss (Traffic): 13.3886
# Epoch [2/100], Train Loss: 2260.8148, Validation Loss: 1884.2136, Validation Loss (Traffic): 5.8428
# Epoch [3/100], Train Loss: 1855.5197, Validation Loss: 1820.1805, Validation Loss (Traffic): 4.5506
# Epoch [4/100], Train Loss: 1697.9628, Validation Loss: 1804.5839, Validation Loss (Traffic): 5.0344
# Epoch [5/100], Train Loss: 1620.4040, Validation Loss: 1687.1222, Validation Loss (Traffic): 4.6691
# Epoch [6/100], Train Loss: 1570.8582, Validation Loss: 1608.7335, Validation Loss (Traffic): 4.1570
# Epoch [7/100], Train Loss: 1541.4606, Validation Loss: 1600.2440, Validation Loss (Traffic): 4.1587
# Epoch [8/100], Train Loss: 1513.8447, Validation Loss: 1613.4906, Validation Loss (Traffic): 4.3467
# Epoch [9/100], Train Loss: 1493.0016, Validation Loss: 1600.7992, Validation Loss (Traffic): 4.1736
# Epoch [10/100], Train Loss: 1478.1260, Validation Loss: 1554.2295, Validation Loss (Traffic): 3.6457
# Epoch [11/100], Train Loss: 1465.0826, Validation Loss: 1526.9838, Validation Loss (Traffic): 3.3478
# Epoch [12/100], Train Loss: 1453.5526, Validation Loss: 1523.6786, Validation Loss (Traffic): 3.2042
# Epoch [13/100], Train Loss: 1444.6563, Validation Loss: 1512.5587, Validation Loss (Traffic): 3.0970
# Epoch [14/100], Train Loss: 1436.2674, Validation Loss: 1503.2878, Validation Loss (Traffic): 2.9937
# Epoch [15/100], Train Loss: 1427.8651, Validation Loss: 1490.0485, Validation Loss (Traffic): 2.9249
# Epoch [16/100], Train Loss: 1421.1448, Validation Loss: 1492.0552, Validation Loss (Traffic): 3.0467
# Epoch [17/100], Train Loss: 1413.1615, Validation Loss: 1491.2218, Validation Loss (Traffic): 2.9434
# Epoch [18/100], Train Loss: 1408.9362, Validation Loss: 1471.2433, Validation Loss (Traffic): 2.5918
# Epoch [19/100], Train Loss: 1403.1910, Validation Loss: 1473.6656, Validation Loss (Traffic): 2.6196
# Epoch [20/100], Train Loss: 1395.3715, Validation Loss: 1462.8645, Validation Loss (Traffic): 2.5405
# Epoch [21/100], Train Loss: 1392.2444, Validation Loss: 1470.6401, Validation Loss (Traffic): 2.6040
# Epoch [22/100], Train Loss: 1389.2630, Validation Loss: 1462.7522, Validation Loss (Traffic): 2.5433
# Epoch [23/100], Train Loss: 1387.0460, Validation Loss: 1469.7136, Validation Loss (Traffic): 2.6014
# Epoch [24/100], Train Loss: 1382.1347, Validation Loss: 1456.3090, Validation Loss (Traffic): 2.4465
# Epoch [25/100], Train Loss: 1379.0410, Validation Loss: 1459.4382, Validation Loss (Traffic): 2.5364
# Epoch [26/100], Train Loss: 1376.4987, Validation Loss: 1454.1482, Validation Loss (Traffic): 2.5680
# Epoch [27/100], Train Loss: 1372.5919, Validation Loss: 1453.2180, Validation Loss (Traffic): 2.5282
# Epoch [28/100], Train Loss: 1369.0924, Validation Loss: 1459.5856, Validation Loss (Traffic): 2.5257
# Epoch [29/100], Train Loss: 1366.6876, Validation Loss: 1471.8839, Validation Loss (Traffic): 2.6075
# Epoch [30/100], Train Loss: 1364.3235, Validation Loss: 1480.7145, Validation Loss (Traffic): 2.7237
# Epoch [31/100], Train Loss: 1361.3536, Validation Loss: 1447.7676, Validation Loss (Traffic): 2.4284
# Epoch [32/100], Train Loss: 1358.0243, Validation Loss: 1474.0021, Validation Loss (Traffic): 2.6719
# Epoch [33/100], Train Loss: 1357.3437, Validation Loss: 1443.5696, Validation Loss (Traffic): 2.5049
# Epoch [34/100], Train Loss: 1353.8742, Validation Loss: 1468.8053, Validation Loss (Traffic): 2.6787
# Epoch [35/100], Train Loss: 1354.0615, Validation Loss: 1445.9247, Validation Loss (Traffic): 2.4314
# Epoch [36/100], Train Loss: 1352.9155, Validation Loss: 1443.4551, Validation Loss (Traffic): 2.5079
# Epoch [37/100], Train Loss: 1353.4513, Validation Loss: 1452.2773, Validation Loss (Traffic): 2.5039
# Epoch [38/100], Train Loss: 1350.6094, Validation Loss: 1445.9808, Validation Loss (Traffic): 2.3954
# Epoch [39/100], Train Loss: 1348.5001, Validation Loss: 1431.5488, Validation Loss (Traffic): 2.3888
# Epoch [40/100], Train Loss: 1346.0054, Validation Loss: 1451.1370, Validation Loss (Traffic): 2.5056
# Epoch [41/100], Train Loss: 1345.7820, Validation Loss: 1431.8459, Validation Loss (Traffic): 2.3706
# Epoch [42/100], Train Loss: 1343.5430, Validation Loss: 1436.8922, Validation Loss (Traffic): 2.4877
# Epoch [43/100], Train Loss: 1342.9114, Validation Loss: 1443.8215, Validation Loss (Traffic): 2.4423
# Epoch [44/100], Train Loss: 1343.1305, Validation Loss: 1441.4426, Validation Loss (Traffic): 2.4285
# Epoch [45/100], Train Loss: 1341.9910, Validation Loss: 1440.7415, Validation Loss (Traffic): 2.4257
# Epoch [46/100], Train Loss: 1341.4427, Validation Loss: 1463.1694, Validation Loss (Traffic): 2.5600
# Epoch [47/100], Train Loss: 1339.2282, Validation Loss: 1437.8656, Validation Loss (Traffic): 2.3463
# Epoch [48/100], Train Loss: 1339.8609, Validation Loss: 1424.6063, Validation Loss (Traffic): 2.3162
# Epoch [49/100], Train Loss: 1338.6458, Validation Loss: 1440.6951, Validation Loss (Traffic): 2.3699
# Epoch [50/100], Train Loss: 1336.5148, Validation Loss: 1435.4822, Validation Loss (Traffic): 2.3986
# Epoch [51/100], Train Loss: 1338.8015, Validation Loss: 1473.6936, Validation Loss (Traffic): 2.6736
# Epoch [52/100], Train Loss: 1338.3582, Validation Loss: 1503.6136, Validation Loss (Traffic): 2.9533
# Epoch [53/100], Train Loss: 1335.1977, Validation Loss: 1438.0569, Validation Loss (Traffic): 2.3937
# Epoch [54/100], Train Loss: 1335.2977, Validation Loss: 1487.9711, Validation Loss (Traffic): 2.8615
# Epoch [55/100], Train Loss: 1335.6317, Validation Loss: 1419.4297, Validation Loss (Traffic): 2.2930
# Epoch [56/100], Train Loss: 1334.7662, Validation Loss: 1429.4349, Validation Loss (Traffic): 2.3420
# Epoch [57/100], Train Loss: 1334.7927, Validation Loss: 1433.8555, Validation Loss (Traffic): 2.3621
# Epoch [58/100], Train Loss: 1333.5892, Validation Loss: 1427.8662, Validation Loss (Traffic): 2.3230
# Epoch [59/100], Train Loss: 1334.3761, Validation Loss: 1431.5219, Validation Loss (Traffic): 2.3433
# Epoch [60/100], Train Loss: 1331.1642, Validation Loss: 1421.9678, Validation Loss (Traffic): 2.3508
# Epoch [61/100], Train Loss: 1332.1696, Validation Loss: 1419.3260, Validation Loss (Traffic): 2.3104
# Epoch [62/100], Train Loss: 1332.4100, Validation Loss: 1440.2201, Validation Loss (Traffic): 2.4567
# Epoch [63/100], Train Loss: 1329.7748, Validation Loss: 1449.6025, Validation Loss (Traffic): 2.4404
# Epoch [64/100], Train Loss: 1331.2683, Validation Loss: 1445.0212, Validation Loss (Traffic): 2.4578
# Epoch [65/100], Train Loss: 1331.2828, Validation Loss: 1421.6909, Validation Loss (Traffic): 2.2981
# Epoch [66/100], Train Loss: 1329.9885, Validation Loss: 1431.4548, Validation Loss (Traffic): 2.3669
# Epoch [67/100], Train Loss: 1329.0120, Validation Loss: 1417.7451, Validation Loss (Traffic): 2.2963
# Epoch [68/100], Train Loss: 1330.3557, Validation Loss: 1421.0947, Validation Loss (Traffic): 2.2857
# Epoch [69/100], Train Loss: 1328.9082, Validation Loss: 1424.1475, Validation Loss (Traffic): 2.2663
# Epoch [70/100], Train Loss: 1328.3076, Validation Loss: 1421.0834, Validation Loss (Traffic): 2.2999
# Epoch [71/100], Train Loss: 1329.8526, Validation Loss: 1469.8822, Validation Loss (Traffic): 2.6800
# Epoch [72/100], Train Loss: 1326.7022, Validation Loss: 1428.5748, Validation Loss (Traffic): 2.3371
# Epoch [73/100], Train Loss: 1326.9369, Validation Loss: 1424.3563, Validation Loss (Traffic): 2.3481
# Epoch [74/100], Train Loss: 1327.5842, Validation Loss: 1421.6879, Validation Loss (Traffic): 2.3291
# Epoch [75/100], Train Loss: 1326.4126, Validation Loss: 1424.8892, Validation Loss (Traffic): 2.2313
# Epoch [76/100], Train Loss: 1326.3725, Validation Loss: 1422.0238, Validation Loss (Traffic): 2.2722
# Epoch [77/100], Train Loss: 1326.3091, Validation Loss: 1425.2018, Validation Loss (Traffic): 2.2803
# Epoch [78/100], Train Loss: 1325.7468, Validation Loss: 1419.9054, Validation Loss (Traffic): 2.3224
# Epoch [79/100], Train Loss: 1325.3445, Validation Loss: 1417.2162, Validation Loss (Traffic): 2.3227
# Epoch [80/100], Train Loss: 1325.2631, Validation Loss: 1430.1682, Validation Loss (Traffic): 2.3459
# Epoch [81/100], Train Loss: 1324.2624, Validation Loss: 1414.0533, Validation Loss (Traffic): 2.2316
# Epoch [82/100], Train Loss: 1324.7574, Validation Loss: 1426.2004, Validation Loss (Traffic): 2.3470
# Epoch [83/100], Train Loss: 1324.2004, Validation Loss: 1442.5167, Validation Loss (Traffic): 2.4392
# Epoch [84/100], Train Loss: 1324.2469, Validation Loss: 1445.3633, Validation Loss (Traffic): 2.5409
# Epoch [85/100], Train Loss: 1323.3963, Validation Loss: 1416.4326, Validation Loss (Traffic): 2.2800
# Epoch [86/100], Train Loss: 1322.6349, Validation Loss: 1422.9238, Validation Loss (Traffic): 2.3657
# Epoch [87/100], Train Loss: 1322.1585, Validation Loss: 1424.3912, Validation Loss (Traffic): 2.3120
# Epoch [88/100], Train Loss: 1321.5613, Validation Loss: 1418.6687, Validation Loss (Traffic): 2.2721
# Epoch [89/100], Train Loss: 1321.5529, Validation Loss: 1426.0063, Validation Loss (Traffic): 2.3282
# Epoch [90/100], Train Loss: 1321.4180, Validation Loss: 1428.0876, Validation Loss (Traffic): 2.3977
# Epoch [91/100], Train Loss: 1322.1045, Validation Loss: 1431.9738, Validation Loss (Traffic): 2.4108
# Epoch [92/100], Train Loss: 1321.2949, Validation Loss: 1423.3380, Validation Loss (Traffic): 2.3102
# Epoch [93/100], Train Loss: 1320.6465, Validation Loss: 1417.2092, Validation Loss (Traffic): 2.2524
# Epoch [94/100], Train Loss: 1323.7897, Validation Loss: 1424.9050, Validation Loss (Traffic): 2.3731
# Epoch [95/100], Train Loss: 1320.3691, Validation Loss: 1421.3472, Validation Loss (Traffic): 2.3360
# Epoch [96/100], Train Loss: 1320.3493, Validation Loss: 1417.7513, Validation Loss (Traffic): 2.2503
# Epoch [97/100], Train Loss: 1319.9323, Validation Loss: 1424.6434, Validation Loss (Traffic): 2.4321
# Epoch [98/100], Train Loss: 1318.7079, Validation Loss: 1421.5415, Validation Loss (Traffic): 2.2689
# Epoch [99/100], Train Loss: 1318.6486, Validation Loss: 1419.5797, Validation Loss (Traffic): 2.2927
# Epoch [100/100], Train Loss: 1318.3244, Validation Loss: 1421.7128, Validation Loss (Traffic): 2.3438

# %%
plt.plot(avg_train_loss_history)
plt.plot(avg_test_loss_history)
plt.show()

# %%
testData = dataProcessor.process(testDataUnit, dataAugment=False)
model, device = createModel(modelConfig)
model.load_checkpoint(f"{modelFolder}/{name}.pth")
results = evaluateModel(model, testData)

plt.plot(results['trafficTarget_actual'][0:100])
plt.plot(results['trafficTarget_predicted'][0:100])
plt.show()
