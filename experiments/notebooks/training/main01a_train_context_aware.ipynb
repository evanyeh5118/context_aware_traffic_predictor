# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import numpy as np
import matplotlib.pyplot as plt

import pickle
import json
import sys
sys.path.append("../../../")

from src.context_aware.config import ModelConfig, TrainingConfig, MetaConfig
from src.dataset_manager import DatasetConvertor 
from src.context_aware.preprocessing import PreprocessingDataset
from src.context_aware.models import createModel
from src.context_aware.training import trainModel
from src.context_aware.evaluation import evaluateModel

# %%
rawDatasetFolder = "../../../data/raw"
dpdrDatasetFolder = "../../../data/processed/dpdr"
configPath = "../../config/combined_flows_forward.json"
modelFolder = "../../../data/models/context_aware"
verbose = True

# %%
datasetConverter = DatasetConvertor(rawDatasetFolder, randomFlag=False)
with open(configPath, "r") as f:
    config = json.load(f)

name = config.get("NAME")
len_window = config.get("LEN_WINDOW")
dim_data = len(config.get("CONTEXT_IDXS"))
train_ratio = config.get("TRAIN_RATIO")

# =============== Preprocessing ===============
datasetConverter.addDataUnit(config)
dataUnit = datasetConverter.getDataUnit(name)
max_vals, min_vals = dataUnit.getMaxMinMbnVals()
metaConfig = MetaConfig.initialize(
    dim_data=dim_data, 
    window_length=len_window, 
    max_vals=max_vals, 
    min_vals=min_vals
)
trainDataUnit, testDataUnit = dataUnit.split(train_ratio)
dataProcessor = PreprocessingDataset(metaConfig)
trainData = dataProcessor.process(trainDataUnit, dataAugment=True, filterMode='filtfilt')
testData = dataProcessor.process(testDataUnit, dataAugment=False, filterMode='filtfilt')

# =============== Training ===============
modelConfig = ModelConfig.from_meta_config(metaConfig)
model, device = createModel(modelConfig)
trainingConfig = TrainingConfig()
model, avg_train_loss_history, avg_test_loss_history = trainModel(
    model, trainData, testData, trainingConfig, verbose=verbose, 
    model_path=f"{modelFolder}/{name}_lenWindow_{len_window}.pth"
)

# =============== Save ===============
testDataUnit.saveDataUnit(f"{dpdrDatasetFolder}/{name}.csv")
with open(f"{modelFolder}/{name}_lenWindow_{len_window}_modelConfig.pkl", "wb") as f:
    pickle.dump(modelConfig, f)
with open(f"{modelFolder}/{name}_lenWindow_{len_window}_metaConfig.pkl", "wb") as f:
    pickle.dump(metaConfig, f)
# Out:
# Size of train loader: 9, Size of test loader: 1
# Used device: cuda:0
# Size of model: 204622
# TrafficPredictorContextAssisted(
#   (dbf2traffic): DeadFeaturesToTrafficLayer(
#     (input_layer): Sequential(
#       (0): Linear(in_features=231, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.8, inplace=False)
#     )
#     (hidden_layers): ModuleList(
#       (0-1): 2 x Sequential(
#         (0): Linear(in_features=256, out_features=256, bias=True)
#         (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.8, inplace=False)
#       )
#     )
#     (trans2transmission_layer): Linear(in_features=256, out_features=20, bias=True)
#     (sigmoid): Sigmoid()
#     (trans2traffic_layer): Linear(in_features=276, out_features=1, bias=True)
#     (trans2trafficClass_layer): Linear(in_features=276, out_features=21, bias=True)
#   )
#   (contextAdjuster): ContextAdjuster(
#     (layers): Sequential(
#       (Linear_1): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_1): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_1): ReLU()
#       (Dropout_1): Dropout(p=0.8, inplace=False)
#       (Linear_2): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_2): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_2): ReLU()
#       (Dropout_2): Dropout(p=0.8, inplace=False)
#       (Linear_3): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_3): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_3): ReLU()
#       (Dropout_3): Dropout(p=0.8, inplace=False)
#       (Linear_4): Linear(in_features=12, out_features=12, bias=True)
#       (BatchNorm_4): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (ReLU_4): ReLU()
#       (Dropout_4): Dropout(p=0.8, inplace=False)
#     )
#     (output_layer): Linear(in_features=12, out_features=12, bias=True)
#     (sigmoid): Sigmoid()
#   )
#   (reluOut): ReLU()
# )
# Epoch [1/100], Train Loss: 7083.6200, Validation Loss: 3756.2649, Validation Loss (Traffic): 15.2479
# Epoch [2/100], Train Loss: 4906.3869, Validation Loss: 3497.6934, Validation Loss (Traffic): 12.0777
# Epoch [3/100], Train Loss: 4138.4236, Validation Loss: 3433.6113, Validation Loss (Traffic): 7.8967
# Epoch [4/100], Train Loss: 3784.4416, Validation Loss: 3389.9448, Validation Loss (Traffic): 6.1780
# Epoch [5/100], Train Loss: 3582.8317, Validation Loss: 3318.7588, Validation Loss (Traffic): 5.7297
# Epoch [6/100], Train Loss: 3453.0379, Validation Loss: 3442.9207, Validation Loss (Traffic): 6.1905
# Epoch [7/100], Train Loss: 3365.3063, Validation Loss: 3731.3652, Validation Loss (Traffic): 10.4006
# Epoch [8/100], Train Loss: 3303.4092, Validation Loss: 3803.5195, Validation Loss (Traffic): 12.0087
# Epoch [9/100], Train Loss: 3256.7296, Validation Loss: 3592.5376, Validation Loss (Traffic): 10.0672
# Epoch [10/100], Train Loss: 3220.1785, Validation Loss: 3367.6101, Validation Loss (Traffic): 6.7054
# Epoch [11/100], Train Loss: 3194.8394, Validation Loss: 3326.8281, Validation Loss (Traffic): 6.1222
# Epoch [12/100], Train Loss: 3173.4114, Validation Loss: 3275.4133, Validation Loss (Traffic): 4.9954
# Epoch [13/100], Train Loss: 3156.2713, Validation Loss: 3277.6045, Validation Loss (Traffic): 5.0896
# Epoch [14/100], Train Loss: 3139.5258, Validation Loss: 3263.7842, Validation Loss (Traffic): 4.7416
# Epoch [15/100], Train Loss: 3127.4412, Validation Loss: 3270.9158, Validation Loss (Traffic): 5.0643
# Epoch [16/100], Train Loss: 3116.3962, Validation Loss: 3255.2632, Validation Loss (Traffic): 4.7540
# Epoch [17/100], Train Loss: 3106.7598, Validation Loss: 3246.2380, Validation Loss (Traffic): 4.4521
# Epoch [18/100], Train Loss: 3097.5582, Validation Loss: 3247.3250, Validation Loss (Traffic): 4.3973
# Epoch [19/100], Train Loss: 3087.8141, Validation Loss: 3248.0540, Validation Loss (Traffic): 4.4100
# Epoch [20/100], Train Loss: 3080.9450, Validation Loss: 3251.0559, Validation Loss (Traffic): 4.4009
# Epoch [21/100], Train Loss: 3074.4915, Validation Loss: 3245.6160, Validation Loss (Traffic): 4.2060
# Epoch [22/100], Train Loss: 3067.2907, Validation Loss: 3272.4172, Validation Loss (Traffic): 4.3835
# Epoch [23/100], Train Loss: 3062.9132, Validation Loss: 3267.9541, Validation Loss (Traffic): 4.3579
# Epoch [24/100], Train Loss: 3058.0346, Validation Loss: 3231.8264, Validation Loss (Traffic): 3.8762
# Epoch [25/100], Train Loss: 3051.9316, Validation Loss: 3232.4749, Validation Loss (Traffic): 3.9752
# Epoch [26/100], Train Loss: 3046.3350, Validation Loss: 3229.6167, Validation Loss (Traffic): 3.8064
# Epoch [27/100], Train Loss: 3041.9390, Validation Loss: 3225.4038, Validation Loss (Traffic): 3.7029
# Epoch [28/100], Train Loss: 3036.9482, Validation Loss: 3231.6287, Validation Loss (Traffic): 3.8227
# Epoch [29/100], Train Loss: 3032.4145, Validation Loss: 3226.9041, Validation Loss (Traffic): 3.7041
# Epoch [30/100], Train Loss: 3029.0785, Validation Loss: 3230.0667, Validation Loss (Traffic): 3.7689
# Epoch [31/100], Train Loss: 3025.2814, Validation Loss: 3230.4797, Validation Loss (Traffic): 3.7013
# Epoch [32/100], Train Loss: 3019.8067, Validation Loss: 3221.7598, Validation Loss (Traffic): 3.7013
# Epoch [33/100], Train Loss: 3018.2345, Validation Loss: 3219.8113, Validation Loss (Traffic): 3.7900
# Epoch [34/100], Train Loss: 3014.2540, Validation Loss: 3215.1055, Validation Loss (Traffic): 3.6724
# Epoch [35/100], Train Loss: 3011.6440, Validation Loss: 3215.1477, Validation Loss (Traffic): 3.6231
# Epoch [36/100], Train Loss: 3009.2884, Validation Loss: 3207.5979, Validation Loss (Traffic): 3.5943
# Epoch [37/100], Train Loss: 3008.1117, Validation Loss: 3210.5098, Validation Loss (Traffic): 3.7056
# Epoch [38/100], Train Loss: 3003.9486, Validation Loss: 3213.1094, Validation Loss (Traffic): 3.7370
# Epoch [39/100], Train Loss: 3002.8615, Validation Loss: 3223.7278, Validation Loss (Traffic): 3.9614
# Epoch [40/100], Train Loss: 3001.0600, Validation Loss: 3208.6409, Validation Loss (Traffic): 3.6513
# Epoch [41/100], Train Loss: 2997.7975, Validation Loss: 3198.3503, Validation Loss (Traffic): 3.6195
# Epoch [42/100], Train Loss: 2996.9644, Validation Loss: 3210.8093, Validation Loss (Traffic): 3.7546
# Epoch [43/100], Train Loss: 2995.3227, Validation Loss: 3211.0063, Validation Loss (Traffic): 3.6627
# Epoch [44/100], Train Loss: 2992.7319, Validation Loss: 3211.8040, Validation Loss (Traffic): 3.7383
# Epoch [45/100], Train Loss: 2990.4681, Validation Loss: 3207.1860, Validation Loss (Traffic): 3.5109
# Epoch [46/100], Train Loss: 2990.3322, Validation Loss: 3196.8364, Validation Loss (Traffic): 3.4811
# Epoch [47/100], Train Loss: 2987.4520, Validation Loss: 3196.0352, Validation Loss (Traffic): 3.5192
# Epoch [48/100], Train Loss: 2986.3261, Validation Loss: 3205.2976, Validation Loss (Traffic): 3.5657
# Epoch [49/100], Train Loss: 2985.2200, Validation Loss: 3201.5698, Validation Loss (Traffic): 3.4883
# Epoch [50/100], Train Loss: 2982.8610, Validation Loss: 3211.0417, Validation Loss (Traffic): 3.5778
# Epoch [51/100], Train Loss: 2981.6431, Validation Loss: 3205.7446, Validation Loss (Traffic): 3.4964
# Epoch [52/100], Train Loss: 2979.5818, Validation Loss: 3198.9119, Validation Loss (Traffic): 3.6051
# Epoch [53/100], Train Loss: 2978.5515, Validation Loss: 3192.2722, Validation Loss (Traffic): 3.4798
# Epoch [54/100], Train Loss: 2977.2025, Validation Loss: 3196.7288, Validation Loss (Traffic): 3.4672
# Epoch [55/100], Train Loss: 2974.7549, Validation Loss: 3195.5757, Validation Loss (Traffic): 3.4488
# Epoch [56/100], Train Loss: 2974.2422, Validation Loss: 3204.1055, Validation Loss (Traffic): 3.4675
# Epoch [57/100], Train Loss: 2972.0163, Validation Loss: 3192.4023, Validation Loss (Traffic): 3.3926
# Epoch [58/100], Train Loss: 2972.3853, Validation Loss: 3230.1062, Validation Loss (Traffic): 3.6727
# Epoch [59/100], Train Loss: 2969.8404, Validation Loss: 3211.2986, Validation Loss (Traffic): 3.4959
# Epoch [60/100], Train Loss: 2969.6038, Validation Loss: 3197.7024, Validation Loss (Traffic): 3.4808
# Epoch [61/100], Train Loss: 2968.3579, Validation Loss: 3224.3071, Validation Loss (Traffic): 3.7524
# Epoch [62/100], Train Loss: 2968.3971, Validation Loss: 3242.6382, Validation Loss (Traffic): 3.8304
# Epoch [63/100], Train Loss: 2966.7795, Validation Loss: 3184.5581, Validation Loss (Traffic): 3.3469
# Epoch [64/100], Train Loss: 2965.3694, Validation Loss: 3187.5388, Validation Loss (Traffic): 3.4302
# Epoch [65/100], Train Loss: 2963.9641, Validation Loss: 3207.3191, Validation Loss (Traffic): 3.5251
# Epoch [66/100], Train Loss: 2962.7360, Validation Loss: 3192.4153, Validation Loss (Traffic): 3.4571
# Epoch [67/100], Train Loss: 2961.4678, Validation Loss: 3188.9150, Validation Loss (Traffic): 3.3987
# Epoch [68/100], Train Loss: 2960.5413, Validation Loss: 3184.1267, Validation Loss (Traffic): 3.3382
# Epoch [69/100], Train Loss: 2960.0141, Validation Loss: 3228.8870, Validation Loss (Traffic): 3.7717
# Epoch [70/100], Train Loss: 2958.5325, Validation Loss: 3193.6421, Validation Loss (Traffic): 3.3924
# Epoch [71/100], Train Loss: 2957.4499, Validation Loss: 3193.8589, Validation Loss (Traffic): 3.4431
# Epoch [72/100], Train Loss: 2956.4303, Validation Loss: 3191.2148, Validation Loss (Traffic): 3.4382
# Epoch [73/100], Train Loss: 2954.4985, Validation Loss: 3182.3867, Validation Loss (Traffic): 3.4050
# Epoch [74/100], Train Loss: 2953.6886, Validation Loss: 3177.8115, Validation Loss (Traffic): 3.3376
# Epoch [75/100], Train Loss: 2954.0312, Validation Loss: 3180.9590, Validation Loss (Traffic): 3.3223
# Epoch [76/100], Train Loss: 2953.0415, Validation Loss: 3187.9736, Validation Loss (Traffic): 3.4228
# Epoch [77/100], Train Loss: 2952.1141, Validation Loss: 3209.6335, Validation Loss (Traffic): 3.8108
# Epoch [78/100], Train Loss: 2950.5243, Validation Loss: 3185.2346, Validation Loss (Traffic): 3.3814
# Epoch [79/100], Train Loss: 2949.9787, Validation Loss: 3172.9626, Validation Loss (Traffic): 3.2955
# Epoch [80/100], Train Loss: 2947.6017, Validation Loss: 3184.1865, Validation Loss (Traffic): 3.4113
# Epoch [81/100], Train Loss: 2947.3965, Validation Loss: 3180.7036, Validation Loss (Traffic): 3.3937
# Epoch [82/100], Train Loss: 2945.7390, Validation Loss: 3176.4788, Validation Loss (Traffic): 3.3189
# Epoch [83/100], Train Loss: 2945.7022, Validation Loss: 3202.0674, Validation Loss (Traffic): 3.5406
# Epoch [84/100], Train Loss: 2946.0474, Validation Loss: 3192.1753, Validation Loss (Traffic): 3.4880
# Epoch [85/100], Train Loss: 2945.3110, Validation Loss: 3212.6184, Validation Loss (Traffic): 3.6502
# Epoch [86/100], Train Loss: 2944.6788, Validation Loss: 3194.6445, Validation Loss (Traffic): 3.5043
# Epoch [87/100], Train Loss: 2944.6953, Validation Loss: 3168.0220, Validation Loss (Traffic): 3.2412
# Epoch [88/100], Train Loss: 2943.4999, Validation Loss: 3180.4766, Validation Loss (Traffic): 3.3356
# Epoch [89/100], Train Loss: 2942.1922, Validation Loss: 3167.7222, Validation Loss (Traffic): 3.2212
# Epoch [90/100], Train Loss: 2941.9875, Validation Loss: 3178.1555, Validation Loss (Traffic): 3.3336
# Epoch [91/100], Train Loss: 2940.2449, Validation Loss: 3185.2224, Validation Loss (Traffic): 3.3494
# Epoch [92/100], Train Loss: 2941.4902, Validation Loss: 3205.3682, Validation Loss (Traffic): 3.7003
# Epoch [93/100], Train Loss: 2940.2675, Validation Loss: 3188.1145, Validation Loss (Traffic): 3.4413
# Epoch [94/100], Train Loss: 2938.5145, Validation Loss: 3170.0811, Validation Loss (Traffic): 3.2698
# Epoch [95/100], Train Loss: 2938.5000, Validation Loss: 3169.7888, Validation Loss (Traffic): 3.2552
# Epoch [96/100], Train Loss: 2937.3864, Validation Loss: 3173.4260, Validation Loss (Traffic): 3.2809
# Epoch [97/100], Train Loss: 2936.7764, Validation Loss: 3175.4744, Validation Loss (Traffic): 3.3397
# Epoch [98/100], Train Loss: 2936.4113, Validation Loss: 3181.7217, Validation Loss (Traffic): 3.3976
# Epoch [99/100], Train Loss: 2935.8160, Validation Loss: 3178.9141, Validation Loss (Traffic): 3.3685
# Epoch [100/100], Train Loss: 2934.0551, Validation Loss: 3179.9045, Validation Loss (Traffic): 3.3885

# %%
plt.plot(avg_train_loss_history)
plt.plot(avg_test_loss_history)
plt.show()

# %%
testData = dataProcessor.process(testDataUnit, dataAugment=False)
model, device = createModel(modelConfig)
model.load_checkpoint(f"{modelFolder}/{name}_lenWindow_{len_window}.pth")
results = evaluateModel(model, testData)

plt.plot(results['trafficTarget_actual'][0:100])
plt.plot(results['trafficTarget_predicted'][0:100])
plt.show()
